# %% [markdown]
# # Introduction
#
# In this notebook, we show and describe the results for a baseline classifier, to be used a confrontation for all of the results in the paper.
#
# As a baseline classifier, we shall employ a majority class prediction, i.e. a classifier which always predicts the class with the most values (which in this case is "stressed").

# %%
from pandas import MultiIndex, DataFrame, concat, set_option, read_csv
from IPython.display import display
from numpy import sqrt, round

def clean_names(x: str):
    if x[0] == "_":
        return x[1:]
    elif x[0] == " ":
        return x[2:-1]
    elif x[-1] == "_":
        return x[:-1]
    else:
        return x

unimodal_sessions: dict[str] = {
    # TODO: missing tests over non-unravelled! ->
    "DUMMY - unimodal - other joins": ["rootsession0"],
    "DUMMY - unimodal - unravelled": [
        "rootsession1",
    ],
}

final_df = DataFrame()
for session_name, sessions in unimodal_sessions.items():
    print(f"{session_name}")
    for session in sessions:
        print(f"Loading session {session}")
        path: str = f"../results/train/dummy/{session}/cross_val.csv"
        data = read_csv(path, index_col=0, engine="c")
        data = data.drop(
            columns=[col for col in data.columns if "deep_features" in col]
        )
        avg_df = data.mean(axis=0)
        new_idx = [
            tuple(
                clean_names(el3)
                for (el) in idx.split("(")
                for el2 in el.split(")")
                for el3 in el2.split(",")
                if el3 != "'hand_crafted_features'"
            )
            for idx in avg_df.index
        ]
        new_idx = [tuple((session_name, *idx)) for idx in new_idx]
        avg_df.index = MultiIndex.from_tuples(
            new_idx,
            names=["Session Name", "Join type", "Feature", "ML Model"],
        )
        new_data = DataFrame()
        new_data['mean'] = round(avg_df * 100, decimals=1).astype(float)
        # new_data['std'] = data.std(axis=0).values
        new_data['se'] = round(data.std(axis=0).values/sqrt(10) * 100, decimals=1).astype(float)

        final_df = concat([final_df, new_data])
    
set_option('display.max_rows', 500)
display(final_df.sort_values(by=['mean'], ascending=False))
# Out:
# DUMMY - unimodal - other joins
# Loading session rootsession0
# DUMMY - unimodal - unravelled
# Loading session rootsession1
#                                                                                   mean  \
# Session Name                   Join type            Feature      ML Model
# DUMMY - unimodal - other joins concat_feature_level ECG_features DummyClassifier  51.8
#                                window_average       ST_features  DummyClassifier  51.4
#                                                     GSR_features DummyClassifier  50.5
#                                concat_feature_level ST_features  DummyClassifier  50.4
#                                window_average       ECG_features DummyClassifier  50.3
# DUMMY - unimodal - unravelled  concat_label_level   ECG_features DummyClassifier  50.3
# DUMMY - unimodal - other joins feature_average      ST_features  DummyClassifier  50.0
# DUMMY - unimodal - unravelled  concat_label_level   GSR_features DummyClassifier  49.9
# DUMMY - unimodal - other joins feature_average      GSR_features DummyClassifier  49.5
# DUMMY - unimodal - unravelled  concat_label_level   ST_features  DummyClassifier  49.3
# DUMMY - unimodal - other joins feature_average      ECG_features DummyClassifier  48.6
#                                concat_feature_level GSR_features DummyClassifier  48.3
#
#                                                                                    se
# Session Name                   Join type            Feature      ML Model
# DUMMY - unimodal - other joins concat_feature_level ECG_features DummyClassifier  1.8
#                                window_average       ST_features  DummyClassifier  1.3
#                                                     GSR_features DummyClassifier  1.3
#                                concat_feature_level ST_features  DummyClassifier  1.2
#                                window_average       ECG_features DummyClassifier  1.0
# DUMMY - unimodal - unravelled  concat_label_level   ECG_features DummyClassifier  1.9
# DUMMY - unimodal - other joins feature_average      ST_features  DummyClassifier  0.8
# DUMMY - unimodal - unravelled  concat_label_level   GSR_features DummyClassifier  2.6
# DUMMY - unimodal - other joins feature_average      GSR_features DummyClassifier  0.8
# DUMMY - unimodal - unravelled  concat_label_level   ST_features  DummyClassifier  1.7
# DUMMY - unimodal - other joins feature_average      ECG_features DummyClassifier  1.1
#                                concat_feature_level GSR_features DummyClassifier  0.9
